# %% [markdown]
# # MoneyPrinterTurbo Setup Guide
#
# This notebook will guide you through the process of setting up [MoneyPrinterTurbo](https://github.com/harry0703/MoneyPrinterTurbo).

# %%
# @title 🔥 一键启动 MoneyPrinterTurbo (官方最新版)
import os
import urllib.request

# 1. 克隆官方仓库 (确保是用最新的功能)
# !git clone https://github.com/FujiwaraChoki/MoneyPrinterTurbo.git
# %cd MoneyPrinterTurbo

# 2. 安装依赖
# !pip install -r requirements.txt
# !apt-get install -y imagemagick
# !sed -i 's/none/read,write/g' /etc/ImageMagick-6/policy.xml

# 3. 安装内网穿透工具 (localtunnel，不需要注册账号)
# !npm install -g localtunnel

# 4. 启动服务
# 获取你的公网 IP (待会儿需要填)
print("==========================================")
print("👇 请复制下方这个 IP 地址：")
print(urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
print("==========================================")

# 后台运行程序并开启穿透
get_ipython().system_raw('streamlit run webui.py &')
# !npx localtunnel --port 8501
